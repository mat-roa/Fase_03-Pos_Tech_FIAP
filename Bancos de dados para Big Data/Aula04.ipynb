# %% [markdown]
# ## BigQuery Integration

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import auth
from google.cloud import bigquery
from google.colab import data_table

project = 'aula01-415719'
location = 'US'
client = bigquery.Client(project = project, location = location)
data_table.enable_dataframe_formatter()
auth.authenticate_user()

# %%
job = client.get_job('bquxjob_12d1de7a_18df68da10b')
results = job.to_dataframe()
results.head(20)
# Out:
#           date    pack  total_sales_dolar  total_transactions
# 0   2012-01-03  123573         1012493.81               10147
# 1   2012-01-04  111053          860053.73                9263
# 2   2012-01-05  114268          940194.93                8795
# 3   2012-01-09  109871          933835.50                9186
# 4   2012-01-10  106619          900077.61                8732
# 5   2012-01-11   94475          773739.73                7692
# 6   2012-01-12  114683          927338.66                8596
# 7   2012-01-16   94381          968646.52                8062
# 8   2012-01-17  109613          921105.56                8995
# 9   2012-01-18   92754          850387.49                7682
# 10  2012-01-19  111315         1021175.90                8654
# 11  2012-01-23   95218          985418.41                8048
# 12  2012-01-24  108849         1013018.29                9180
# 13  2012-01-25   94883          764709.31                7904
# 14  2012-01-26  115230         1016554.79                8968
# 15  2012-01-27     310             796.36                  29
# 16  2012-01-30   97208          986696.53                8327
# 17  2012-01-31  111825         1039951.09                9510
# 18  2012-02-01  102843          906994.66                8561
# 19  2012-02-02  124395         1218272.00                9718

# %%
results.describe()
# Out:
#                 pack  total_sales_dolar  total_transactions
# count         3126.0       3.126000e+03              3126.0
# mean   110275.108445       1.311020e+06         9081.663468
# std     38698.470984       5.037800e+05         3177.730217
# min              4.0       4.064000e+01                 1.0
# 25%         98207.25       1.116358e+06             8084.75
# 50%         118138.5       1.377169e+06              9783.5
# 75%         134488.0       1.618157e+06             11027.5
# max         214338.0       3.516318e+06             18965.0
